# %%
#Example HNF
M = Matrix(ZZ, [
    [15, 25, -12, 71],
    [-47, -66, 20, 68]
])

U, H = M.hermite_form(transformation=True)
print(U)
print(H)
# Out:
# [   1   88 -124 2038]
# [   0  185 -264 4357]
# [22  7]
# [47 15]

# %%
#Example HNF crypto-sized
def PrintMatrix(M):
    for row in M.rows():
        print("[" + " ".join(map(str, row)) + "]")
M = Matrix(ZZ,[
  [20735063, -27810961, 6066691, 20223581, 25676517, -6481013],
  [56609234, -20539641, -49316771, -51934742, 2068323, -18483814],
  [-68715500, -27218201, 39848498, -40701960, 70234327, 8732415],
  [4781915, -16469156, -2826594, -16253431, 19986683, 123766149],
])
U, H = M.hermite_form(transformation=True)
PrintMatrix(U)
# Out:
# [1 0 0 3 -5 -4130146786169722707689238313415]
# [0 1 0 0 2 3111137699910746452490082391305]
# [0 0 1 0 8 7518386154962714494075118681635]
# [0 0 0 4 -13 -12057742755111933468654359241526]
